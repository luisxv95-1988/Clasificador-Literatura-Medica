# %% [markdown]
# # Exploración de Datos
# Este notebook carga y analiza el dataset de literatura médica.

# %%
import sys
sys.path.append("../src")
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from data_utils import load_data

# Cargar dataset
df = load_data("../challenge_data-18-ago.csv")
df.head()

# %%
# Distribución de clases
plt.figure(figsize=(10,5))
sns.countplot(y=df['group'], order=df['group'].value_counts().index)
plt.title('Distribución de grupos médicos')
plt.show()
