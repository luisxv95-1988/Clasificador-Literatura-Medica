# %% [markdown]
# # Entrenamiento del Modelo
# Este notebook entrena el clasificador de literatura médica usando src/train.py

# %%
import sys
sys.path.append("../src")
from train import train_model, evaluate_model
from data_utils import load_data

# Cargar dataset
df = load_data("../challenge_data-18-ago.csv")
X = df['text']
y = df['group']

# Entrenar modelo
model, X_test, y_test, y_pred = train_model(X, y)

# Evaluar modelo
evaluate_model(y_test, y_pred, model)
